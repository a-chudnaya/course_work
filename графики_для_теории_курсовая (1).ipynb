# %% [markdown]
# ## Импорты и установка модулей и библиотек

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Генерация данных

# %%
dates = pd.date_range(start="2020-01-01", periods=48, freq="M")
values = [i + 5 * (i % 12) + 2 * (i % 3) for i in range(48)]
series = pd.Series(values, index=dates)

# %% [markdown]
# ## Аддитивная декомпозиция

# %%
result = seasonal_decompose(series, model='additive')

fig, (ax1, ax2, ax3, ax4) = plt.subplots(4, 1, figsize=(10, 8))
fig.suptitle('Декомпозиция временного ряда', fontsize=14)

# Исходный ряд
result.observed.plot(ax=ax1, color='blue', title='Исходный временной ряд', legend=False)
ax1.set_ylabel('Значение')

# Тренд
result.trend.plot(ax=ax2, color='red', title='Тренд', legend=False)
ax2.set_ylabel('Значение')

# Сезонность
result.seasonal.plot(ax=ax3, color='green', title='Сезонность', legend=False)
ax3.set_ylabel('Значение')

# Шум (остатки)
result.resid.plot(ax=ax4, color='purple', title='Шум (остатки)', legend=False)
ax4.set_ylabel('Значение')

# Настройка отображения
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-2-36d4e538b20e>:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(start="2020-01-01", periods=48, freq="M")

# %%
values
# Out:
# [0,
#  8,
#  16,
#  18,
#  26,
#  34,
#  36,
#  44,
#  52,
#  54,
#  62,
#  70,
#  12,
#  20,
#  28,
#  30,
#  38,
#  46,
#  48,
#  56,
#  64,
#  66,
#  74,
#  82,
#  24,
#  32,
#  40,
#  42,
#  50,
#  58,
#  60,
#  68,
#  76,
#  78,
#  86,
#  94,
#  36,
#  44,
#  52,
#  54,
#  62,
#  70,
#  72,
#  80,
#  88,
#  90,
#  98,
#  106]

# %%
dates
# Out:
# DatetimeIndex(['2020-01-31', '2020-02-29', '2020-03-31', '2020-04-30',
#                '2020-05-31', '2020-06-30', '2020-07-31', '2020-08-31',
#                '2020-09-30', '2020-10-31', '2020-11-30', '2020-12-31',
#                '2021-01-31', '2021-02-28', '2021-03-31', '2021-04-30',
#                '2021-05-31', '2021-06-30', '2021-07-31', '2021-08-31',
#                '2021-09-30', '2021-10-31', '2021-11-30', '2021-12-31',
#                '2022-01-31', '2022-02-28', '2022-03-31', '2022-04-30',
#                '2022-05-31', '2022-06-30', '2022-07-31', '2022-08-31',
#                '2022-09-30', '2022-10-31', '2022-11-30', '2022-12-31',
#                '2023-01-31', '2023-02-28', '2023-03-31', '2023-04-30',
#                '2023-05-31', '2023-06-30', '2023-07-31', '2023-08-31',
#                '2023-09-30', '2023-10-31', '2023-11-30', '2023-12-31'],
#               dtype='datetime64[ns]', freq='ME')

# %%
series1 = series.dropna()

# %%
series1
# Out:
# 2020-01-31      0
# 2020-02-29      8
# 2020-03-31     16
# 2020-04-30     18
# 2020-05-31     26
# 2020-06-30     34
# 2020-07-31     36
# 2020-08-31     44
# 2020-09-30     52
# 2020-10-31     54
# 2020-11-30     62
# 2020-12-31     70
# 2021-01-31     12
# 2021-02-28     20
# 2021-03-31     28
# 2021-04-30     30
# 2021-05-31     38
# 2021-06-30     46
# 2021-07-31     48
# 2021-08-31     56
# 2021-09-30     64
# 2021-10-31     66
# 2021-11-30     74
# 2021-12-31     82
# 2022-01-31     24
# 2022-02-28     32
# 2022-03-31     40
# 2022-04-30     42
# 2022-05-31     50
# 2022-06-30     58
# 2022-07-31     60
# 2022-08-31     68
# 2022-09-30     76
# 2022-10-31     78
# 2022-11-30     86
# 2022-12-31     94
# 2023-01-31     36
# 2023-02-28     44
# 2023-03-31     52
# 2023-04-30     54
# 2023-05-31     62
# 2023-06-30     70
# 2023-07-31     72
# 2023-08-31     80
# 2023-09-30     88
# 2023-10-31     90
# 2023-11-30     98
# 2023-12-31    106
# Freq: ME, dtype: int64

# %%
series1 = series[series != 0]

# %%
series1
# Out:
# 2020-02-29      8
# 2020-03-31     16
# 2020-04-30     18
# 2020-05-31     26
# 2020-06-30     34
# 2020-07-31     36
# 2020-08-31     44
# 2020-09-30     52
# 2020-10-31     54
# 2020-11-30     62
# 2020-12-31     70
# 2021-01-31     12
# 2021-02-28     20
# 2021-03-31     28
# 2021-04-30     30
# 2021-05-31     38
# 2021-06-30     46
# 2021-07-31     48
# 2021-08-31     56
# 2021-09-30     64
# 2021-10-31     66
# 2021-11-30     74
# 2021-12-31     82
# 2022-01-31     24
# 2022-02-28     32
# 2022-03-31     40
# 2022-04-30     42
# 2022-05-31     50
# 2022-06-30     58
# 2022-07-31     60
# 2022-08-31     68
# 2022-09-30     76
# 2022-10-31     78
# 2022-11-30     86
# 2022-12-31     94
# 2023-01-31     36
# 2023-02-28     44
# 2023-03-31     52
# 2023-04-30     54
# 2023-05-31     62
# 2023-06-30     70
# 2023-07-31     72
# 2023-08-31     80
# 2023-09-30     88
# 2023-10-31     90
# 2023-11-30     98
# 2023-12-31    106
# Freq: ME, dtype: int64

# %% [markdown]
# ## Мультипликативная декомпозиция

# %%
result_mul = seasonal_decompose(series1, model='multiplicative')
# result_mul.plot()
# plt.show()

# Создаем фигуру и оси
fig, (ax1, ax2, ax3, ax4) = plt.subplots(4, 1, figsize=(10, 8))
fig.suptitle('Декомпозиция временного ряда', fontsize=14)

# Исходный ряд
result_mul.observed.plot(ax=ax1, color='blue', title='Исходный временной ряд', legend=False)
ax1.set_ylabel('Значение')

# Тренд
result_mul.trend.plot(ax=ax2, color='red', title='Тренд', legend=False)
ax2.set_ylabel('Значение')

# Сезонность
result_mul.seasonal.plot(ax=ax3, color='green', title='Сезонность', legend=False)
ax3.set_ylabel('Значение')

# Шум (остатки)
result_mul.resid.plot(ax=ax4, color='purple', title='Шум (остатки)', legend=False)
ax4.set_ylabel('Значение')

# Настройка отображения
plt.tight_layout()
plt.show()
